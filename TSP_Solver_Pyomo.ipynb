# %%
#Importing Reuired Libraries

import numpy as np
import pandas as pd
from pyomo.environ import *
import matplotlib.pyplot as plt
import time
import networkx as nx

# %% [markdown]
# Required paths

# %%
glpk_solver_exe_file = 'C:\\Users\\Ashish\\winglpk-4.65\\glpk-4.65\\w64\\glpsol.exe'

name_of_input_file = 'tsp29.txt'

# %% [markdown]
# Writing required functions

# %%
#function to reverse a tuple
def Reverse(tuples):
    new_tup = tuples[::-1]
    return new_tup

#function to detect cycles from solution and returning nested list of cycles with
#first list containg (0,j)&(i,0)
def cycle_det(active_arcs):
    duplicat_arcs=list()
    for i,j in active_arcs:
        duplicat_arcs.append((i,j))
    cycle_iter_var = 0
    cycle_list = list()
    while True:
        g = nx.Graph()
        g.add_edges_from(duplicat_arcs)
        try:
            cycle = nx.find_cycle(g)
            #print(f'Cycle {cycle_iter_var} is ______{cycle}')
            cycle_list.append(cycle)
        except:
            #print('all arcs done')
            break
        for i,j in cycle:
            duplicat_arcs.remove((i,j))
    cycle_iter_var = cycle_iter_var+1
    cycle_list_start_with_0=[]
    for i in cycle_list:
        for tup in i:
            if tup[0]==0 or tup[1]==0:
                cycle_list_start_with_0.append(i)
                continue
        cycle_list_start_with_0.append(i)
    if len(cycle_list)==1:
        return 0
    else:
        return cycle_list_start_with_0

# %% [markdown]
# Reading the input files

# %%
#taking user input
fh = open(f'Input\\{name_of_input_file}')
#marking start time
start_time = time.time()
#reading the text file
loc_x = list()
loc_y = list()
for i in fh:
    a = i.split()
    loc_x.append(float(a[1]))
    loc_y.append(float(a[2]))
n = len(loc_x)
#creating nodes and edges
cities = [i for i in range(n)]
edges = [(i,j) for i in cities for j in cities if i!=j]
#input plot
plt.figure(figsize=(20, 10))
plt.scatter(loc_x,loc_y,color='blue')
plt.xlabel("Distance X")
plt.ylabel("Distance Y")
plt.title("Data points for Djibouti")
s = []
for n in range(len(loc_x)):
    s_temp= []
    s_temp.append("%.lf"%loc_x[n])
    s_temp.append("%.lf"%loc_y[n])
    s.append(s_temp)
#for n in range(len(loc_x)):
#   plt.annotate(str(s[n]),xy=(loc_x[n],loc_y[n]),xytext=(loc_x[n]-4,loc_y[n]-5), color='red')
for n in range(len(loc_x)):
    plt.annotate(str(n),xy=(loc_x[n],loc_y[n]),xytext=(loc_x[n]+4,loc_y[n]+10), color='red')
plt.savefig('Output\\Images\\frame_0.png')

#Calculate euclidiean distance
distance  = {(i,j):np.hypot(loc_x[i]-loc_x[j],loc_y[i]-loc_y[j]) for i,j in edges}

# %% [markdown]
# Creating the MILP Model

# %%
# Defining the model
model = ConcreteModel()

# Defining sets
model.cities = Set(initialize=cities)
model.edges = Set(initialize=edges, dimen=2)

# %% [markdown]
# Defining Variables and Objective function

# %%
# Defining variable for model
model.x = Var(model.edges, within=Binary)

# Objective function
def obj_rule(model):
    return sum(distance[i, j] * model.x[i, j] for i, j in model.edges)

model.obj = Objective(rule=obj_rule, sense=minimize)

# %% [markdown]
# Writing required constraints

# %%
# Constraints
def out_degree_rule(model, c):
    return sum(model.x[i, j] for i, j in model.edges if i == c) == 1

def in_degree_rule(model, c):
    return sum(model.x[i, j] for i, j in model.edges if j == c) == 1

model.out_degree = Constraint(model.cities, rule=out_degree_rule)
model.in_degree = Constraint(model.cities, rule=in_degree_rule)

# Subtour elimination for 2 cities
def subtour_elimination_rule(model, i, j, k, l):
    if i == l and j == k:
        return model.x[i, j] + model.x[k, l] <= 1
    return Constraint.Skip

model.subtour_elimination = Constraint(model.edges, model.edges, rule=subtour_elimination_rule)

# %% [markdown]
# Iniial solve of TSP without Subtour Elemination Constraints

# %%
# Solving the problem initially
solver = SolverFactory('glpk',executable=glpk_solver_exe_file)
solution = solver.solve(model, tee=True)
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmp4vdix33w.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmpz3ru207z.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpydx_xxtd.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpydx_xxtd.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpydx_xxtd.pyomo.lp:7492: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpydx_xxtd.pyomo.lp:7492: warning: upper bound of variable 'x2' redefined
# 870 rows, 812 columns, 3248 non-zeros
# 812 integer variables, all of which are binary
# 8304 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmpz3ru207z.glpk.glp'...
# 6615 lines were written
# GLPK Integer Optimizer, v4.65
# 870 rows, 812 columns, 3248 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 870 rows, 812 columns, 3248 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 869
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 870 rows, 812 columns, 3248 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      82: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   200: obj =   2.359608513e+04 inf =   7.383e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   200: mip =     not found yet >=              -inf        (1; 0)
# +   213: >>>>>   2.452595637e+04 >=   2.375925211e+04   3.1% (4; 0)
# +   221: >>>>>   2.405758148e+04 >=   2.384131555e+04   0.9% (4; 1)
# +   229: mip =   2.405758148e+04 >=     tree is empty   0.0% (0; 9)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 1.7 Mb (1756048 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmp4vdix33w.glpk.raw'...
# 1691 lines were written

# %% [markdown]
# Solving TSP iteratively, ST after each loop we detect the subtours created and solve the same

# %%
# Extracting the active arcs
active_arcs = [(i, j) for i, j in model.edges if model.x[i, j].value > 0.9]

model.subtour_elimination_dynamic = ConstraintList()
# Solving in loop that is adding necessary SEC
frame = 1
while True:
    x_1 = cycle_det(active_arcs)
    if x_1 == 0:
        print('Optimal path found')
        optimal_path = active_arcs
        print('Objective value is', value(model.obj))
        print(f'Code took {(time.time() - start_time)} seconds to execute')
        print(f'Active arcs are {optimal_path}')
        break
    else:
        for i in range(len(x_1) - 1):
            i = (len(x_1) - 1) - i
            sub_cycle = x_1[i]
            model.subtour_elimination_dynamic.add(sum(model.x[j] for j in sub_cycle) <= len(sub_cycle) - 1)
            model.subtour_elimination_dynamic.add(sum(model.x[Reverse(j)] for j in sub_cycle) <= len(sub_cycle) - 1)
            #Plot intermediate plots
            plt.figure(figsize=(20, 10))
            plt.xlabel("Distance X")
            plt.xlabel("Distance Y")
            plt.title("Intermediate Subtours")
            plt.scatter(loc_x, loc_y, color='blue', zorder=1)
            for i, j in active_arcs:
                plt.plot([loc_x[i], loc_x[j]], [loc_y[i], loc_y[j]], color='blue', zorder=1)
            for n in range(len(loc_x)):
                plt.annotate(str(n), xy=(loc_x[n], loc_y[n]), xytext=(loc_x[n] + 4, loc_y[n] + 10), color='red')
            plt.savefig(f'Output\\Images\\frame_{frame}.png')
            frame += 1
        solution = solver.solve(model, tee=True)
        active_arcs = [(i, j) for i, j in model.edges if model.x[i, j].value > 0.9]

# Plotting the output
plt.figure(figsize=(20, 10))
plt.xlabel("Distance X")
plt.xlabel("Distance Y")
plt.title("Solution to the TSP")
plt.scatter(loc_x, loc_y, color='blue', zorder=1)
for i, j in active_arcs:
    plt.plot([loc_x[i], loc_x[j]], [loc_y[i], loc_y[j]], color='blue', zorder=1)
for n in range(len(loc_x)):
    plt.annotate(str(n), xy=(loc_x[n], loc_y[n]), xytext=(loc_x[n] + 4, loc_y[n] + 10), color='red')
plt.savefig(f'Output\\Images\\frame_{frame}.png')
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmpantya37n.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmpcqp2annl.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpx_zu7l73.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpx_zu7l73.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpx_zu7l73.pyomo.lp:7610: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpx_zu7l73.pyomo.lp:7610: warning: upper bound of variable 'x2' redefined
# 888 rows, 812 columns, 3312 non-zeros
# 812 integer variables, all of which are binary
# 8422 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmpcqp2annl.glpk.glp'...
# 6715 lines were written
# GLPK Integer Optimizer, v4.65
# 888 rows, 812 columns, 3312 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 18 hidden covering inequaliti(es) were detected
# 888 rows, 812 columns, 3312 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 887
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 888 rows, 812 columns, 3312 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   220: obj =   2.359608513e+04 inf =   7.772e-16 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   220: mip =     not found yet >=              -inf        (1; 0)
# +   270: >>>>>   2.633754828e+04 >=   2.526161003e+04   4.1% (7; 0)
# +   425: >>>>>   2.631083924e+04 >=   2.619178814e+04   0.5% (18; 13)
# +   467: >>>>>   2.629123488e+04 >=   2.627227321e+04 < 0.1% (15; 22)
# +   479: mip =   2.629123488e+04 >=     tree is empty   0.0% (0; 67)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 1.9 Mb (1948668 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmpantya37n.glpk.raw'...
# 1709 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmpyfrus929.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmp1cw6zr_b.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpsdg8m4_x.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpsdg8m4_x.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpsdg8m4_x.pyomo.lp:7724: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpsdg8m4_x.pyomo.lp:7724: warning: upper bound of variable 'x2' redefined
# 898 rows, 812 columns, 3396 non-zeros
# 812 integer variables, all of which are binary
# 8536 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmp1cw6zr_b.glpk.glp'...
# 6819 lines were written
# GLPK Integer Optimizer, v4.65
# 898 rows, 812 columns, 3396 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 28 hidden covering inequaliti(es) were detected
# 898 rows, 812 columns, 3396 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 897
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 898 rows, 812 columns, 3396 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   304: >>>>>   2.741517692e+04 >=   2.526161003e+04   7.9% (13; 0)
# +   502: >>>>>   2.721440783e+04 >=   2.602129968e+04   4.4% (45; 7)
# +   568: >>>>>   2.691458570e+04 >=   2.602129968e+04   3.3% (55; 12)
# +   654: >>>>>   2.686963538e+04 >=   2.604090404e+04   3.1% (52; 36)
# +   793: >>>>>   2.653746388e+04 >=   2.607287291e+04   1.8% (73; 40)
# +  1517: mip =   2.653746388e+04 >=     tree is empty   0.0% (0; 283)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.4 secs
# Memory used: 2.2 Mb (2286560 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmpyfrus929.glpk.raw'...
# 1719 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmpykl9f948.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmptm0xvouf.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpxv180gpt.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpxv180gpt.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpxv180gpt.pyomo.lp:7832: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpxv180gpt.pyomo.lp:7832: warning: upper bound of variable 'x2' redefined
# 906 rows, 812 columns, 3480 non-zeros
# 812 integer variables, all of which are binary
# 8644 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmptm0xvouf.glpk.glp'...
# 6919 lines were written
# GLPK Integer Optimizer, v4.65
# 906 rows, 812 columns, 3480 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 36 hidden covering inequaliti(es) were detected
# 906 rows, 812 columns, 3480 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 905
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 906 rows, 812 columns, 3480 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   332: >>>>>   2.839801523e+04 >=   2.526161003e+04  11.0% (18; 0)
# +   460: >>>>>   2.828026861e+04 >=   2.528608551e+04  10.6% (37; 1)
# +   544: >>>>>   2.796707551e+04 >=   2.592098621e+04   7.3% (49; 8)
# +   665: >>>>>   2.789000443e+04 >=   2.602129968e+04   6.7% (58; 21)
# +   738: >>>>>   2.784626583e+04 >=   2.604090404e+04   6.5% (69; 25)
# +   855: >>>>>   2.783029163e+04 >=   2.607287291e+04   6.3% (85; 30)
# +   938: >>>>>   2.772188925e+04 >=   2.607287291e+04   5.9% (96; 31)
# +  1144: >>>>>   2.740651432e+04 >=   2.611395180e+04   4.7% (115; 47)
# +  1253: >>>>>   2.706889136e+04 >=   2.624200801e+04   3.1% (101; 105)
# +  1504: >>>>>   2.704211126e+04 >=   2.628758298e+04   2.8% (93; 171)
# +  1730: >>>>>   2.703695181e+04 >=   2.635939209e+04   2.5% (104; 187)
# +  1889: >>>>>   2.696059602e+04 >=   2.642224326e+04   2.0% (117; 195)
# +  2914: >>>>>   2.695342027e+04 >=   2.690907012e+04   0.2% (38; 443)
# +  3012: mip =   2.695342027e+04 >=     tree is empty   0.0% (0; 613)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.6 secs
# Memory used: 2.4 Mb (2558314 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmpykl9f948.glpk.raw'...
# 1727 lines were written
# c:\Users\Ashish\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmp01j0l7t5.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmpct9i7yqf.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmprw1fgo37.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmprw1fgo37.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmprw1fgo37.pyomo.lp:7940: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmprw1fgo37.pyomo.lp:7940: warning: upper bound of variable 'x2' redefined
# 914 rows, 812 columns, 3564 non-zeros
# 812 integer variables, all of which are binary
# 8752 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmpct9i7yqf.glpk.glp'...
# 7019 lines were written
# GLPK Integer Optimizer, v4.65
# 914 rows, 812 columns, 3564 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 44 hidden covering inequaliti(es) were detected
# 914 rows, 812 columns, 3564 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 913
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 914 rows, 812 columns, 3564 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   328: >>>>>   2.824471926e+04 >=   2.526161003e+04  10.6% (21; 0)
# +   533: >>>>>   2.814884578e+04 >=   2.592098621e+04   7.9% (61; 2)
# +   676: >>>>>   2.813923358e+04 >=   2.602129968e+04   7.5% (81; 4)
# +   764: >>>>>   2.798459486e+04 >=   2.602129968e+04   7.0% (96; 5)
# +   838: >>>>>   2.776545912e+04 >=   2.604090404e+04   6.2% (105; 19)
# +  1151: >>>>>   2.775003925e+04 >=   2.609434745e+04   6.0% (134; 47)
# +  1244: >>>>>   2.745937876e+04 >=   2.611395180e+04   4.9% (141; 54)
# +  1451: >>>>>   2.736128617e+04 >=   2.626161237e+04   4.0% (119; 139)
# +  1910: >>>>>   2.733256199e+04 >=   2.635823856e+04   3.6% (142; 206)
# +  1989: >>>>>   2.704607163e+04 >=   2.635939209e+04   2.5% (142; 224)
# +  3219: mip =   2.704607163e+04 >=     tree is empty   0.0% (0; 653)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.7 secs
# Memory used: 2.4 Mb (2559624 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmp01j0l7t5.glpk.raw'...
# 1735 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmp_41r9ry5.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmp0d1alaac.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmp8swga0jq.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmp8swga0jq.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmp8swga0jq.pyomo.lp:8042: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmp8swga0jq.pyomo.lp:8042: warning: upper bound of variable 'x2' redefined
# 920 rows, 812 columns, 3648 non-zeros
# 812 integer variables, all of which are binary
# 8854 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmp0d1alaac.glpk.glp'...
# 7115 lines were written
# GLPK Integer Optimizer, v4.65
# 920 rows, 812 columns, 3648 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 50 hidden covering inequaliti(es) were detected
# 920 rows, 812 columns, 3648 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 919
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 920 rows, 812 columns, 3648 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   321: >>>>>   2.818465729e+04 >=   2.526161003e+04  10.4% (17; 0)
# +   529: >>>>>   2.802450861e+04 >=   2.592098621e+04   7.5% (54; 4)
# +   824: >>>>>   2.748959248e+04 >=   2.604090404e+04   5.3% (88; 19)
# +  1013: >>>>>   2.731079680e+04 >=   2.607287291e+04   4.5% (82; 79)
# +  2075: >>>>>   2.722934846e+04 >=   2.643699633e+04   2.9% (155; 139)
# +  4481: >>>>>   2.720256835e+04 >=   2.701651821e+04   0.7% (167; 386)
# +  5552: mip =   2.720256835e+04 >=     tree is empty   0.0% (0; 995)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   1.2 secs
# Memory used: 2.9 Mb (3029332 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmp_41r9ry5.glpk.raw'...
# 1741 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmplx4g2uz8.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmpsxuk2hzn.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpo_pm7yef.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpo_pm7yef.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpo_pm7yef.pyomo.lp:8132: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpo_pm7yef.pyomo.lp:8132: warning: upper bound of variable 'x2' redefined
# 928 rows, 812 columns, 3714 non-zeros
# 812 integer variables, all of which are binary
# 8944 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmpsxuk2hzn.glpk.glp'...
# 7197 lines were written
# GLPK Integer Optimizer, v4.65
# 928 rows, 812 columns, 3714 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 58 hidden covering inequaliti(es) were detected
# 928 rows, 812 columns, 3714 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 927
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 928 rows, 812 columns, 3714 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   357: >>>>>   2.887284557e+04 >=   2.526161003e+04  12.5% (22; 0)
# +   462: >>>>>   2.808934111e+04 >=   2.528608551e+04  10.0% (40; 5)
# +   682: >>>>>   2.804117986e+04 >=   2.602783447e+04   7.2% (62; 23)
# +   732: >>>>>   2.789000443e+04 >=   2.602783447e+04   6.7% (65; 30)
# +   808: >>>>>   2.775633929e+04 >=   2.604090404e+04   6.2% (73; 37)
# +   874: >>>>>   2.765845486e+04 >=   2.604090404e+04   5.8% (76; 50)
# +  1087: >>>>>   2.760814712e+04 >=   2.613848379e+04   5.3% (95; 74)
# +  1324: >>>>>   2.752796968e+04 >=   2.625091151e+04   4.6% (126; 87)
# +  1574: >>>>>   2.745868234e+04 >=   2.627070779e+04   4.3% (144; 109)
# +  1817: >>>>>   2.727894130e+04 >=   2.633978774e+04   3.4% (171; 122)
# +  8978: mip =   2.727894130e+04 >=     tree is empty   0.0% (0; 1863)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   2.1 secs
# Memory used: 3.6 Mb (3814064 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmplx4g2uz8.glpk.raw'...
# 1749 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmpxq4gd8t5.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmpz88133ev.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmp08pxafer.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmp08pxafer.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmp08pxafer.pyomo.lp:8222: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmp08pxafer.pyomo.lp:8222: warning: upper bound of variable 'x2' redefined
# 936 rows, 812 columns, 3780 non-zeros
# 812 integer variables, all of which are binary
# 9034 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmpz88133ev.glpk.glp'...
# 7279 lines were written
# GLPK Integer Optimizer, v4.65
# 936 rows, 812 columns, 3780 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 66 hidden covering inequaliti(es) were detected
# 936 rows, 812 columns, 3780 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 935
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 936 rows, 812 columns, 3780 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   7.803e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   326: >>>>>   2.843056073e+04 >=   2.526161003e+04  11.1% (17; 0)
# +   420: >>>>>   2.795746917e+04 >=   2.528608551e+04   9.6% (28; 5)
# +   643: >>>>>   2.746086829e+04 >=   2.602783447e+04   5.2% (51; 15)
# +  2275: >>>>>   2.734168182e+04 >=   2.642298268e+04   3.4% (238; 71)
# +  3909: >>>>>   2.733256199e+04 >=   2.662716954e+04   2.6% (326; 192)
# +  9509: mip =   2.733256199e+04 >=     tree is empty   0.0% (0; 1845)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   2.1 secs
# Memory used: 3.7 Mb (3846556 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmpxq4gd8t5.glpk.raw'...
# 1757 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmp2tfdyi5y.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmpw34r_bjt.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpwq7xeagv.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpwq7xeagv.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpwq7xeagv.pyomo.lp:8340: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpwq7xeagv.pyomo.lp:8340: warning: upper bound of variable 'x2' redefined
# 944 rows, 812 columns, 3874 non-zeros
# 812 integer variables, all of which are binary
# 9152 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmpw34r_bjt.glpk.glp'...
# 7389 lines were written
# GLPK Integer Optimizer, v4.65
# 944 rows, 812 columns, 3874 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 74 hidden covering inequaliti(es) were detected
# 944 rows, 812 columns, 3874 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 943
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 944 rows, 812 columns, 3874 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   349: >>>>>   2.886024495e+04 >=   2.526161003e+04  12.5% (21; 0)
# +   461: >>>>>   2.818980535e+04 >=   2.528608551e+04  10.3% (40; 1)
# +   683: >>>>>   2.812594068e+04 >=   2.602783447e+04   7.5% (61; 25)
# +   781: >>>>>   2.802094072e+04 >=   2.602783447e+04   7.1% (74; 30)
# +   860: >>>>>   2.775633929e+04 >=   2.605568523e+04   6.1% (83; 41)
# +  1071: >>>>>   2.770304114e+04 >=   2.611395180e+04   5.7% (95; 63)
# +  1426: >>>>>   2.770160107e+04 >=   2.625091151e+04   5.2% (133; 82)
# +  1566: >>>>>   2.750102236e+04 >=   2.627777327e+04   4.4% (149; 85)
# +  4527: >>>>>   2.734692954e+04 >=   2.660538808e+04   2.7% (412; 232)
# + 11778: mip =   2.734692954e+04 >=     tree is empty   0.0% (0; 2447)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   2.7 secs
# Memory used: 4.2 Mb (4379052 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmp2tfdyi5y.glpk.raw'...
# 1765 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmpnsbv5bi1.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmp3ii8e7fr.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpd2nqes_7.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpd2nqes_7.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpd2nqes_7.pyomo.lp:8442: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpd2nqes_7.pyomo.lp:8442: warning: upper bound of variable 'x2' redefined
# 950 rows, 812 columns, 3958 non-zeros
# 812 integer variables, all of which are binary
# 9254 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmp3ii8e7fr.glpk.glp'...
# 7485 lines were written
# GLPK Integer Optimizer, v4.65
# 950 rows, 812 columns, 3958 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 80 hidden covering inequaliti(es) were detected
# 950 rows, 812 columns, 3958 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 949
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 950 rows, 812 columns, 3958 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   4.998e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   331: >>>>>   2.884127093e+04 >=   2.526161003e+04  12.4% (21; 0)
# +   451: >>>>>   2.818980535e+04 >=   2.530568986e+04  10.2% (40; 1)
# +   606: >>>>>   2.780277973e+04 >=   2.602129968e+04   6.4% (58; 9)
# +  1449: >>>>>   2.762611557e+04 >=   2.627123848e+04   4.9% (137; 38)
# +  2602: >>>>>   2.742524188e+04 >=   2.645177752e+04   3.5% (265; 93)
# +  7508: >>>>>   2.737536650e+04 >=   2.710947896e+04   1.0% (350; 544)
# +  7568: >>>>>   2.737378202e+04 >=   2.711496907e+04   0.9% (285; 687)
# +  9819: mip =   2.737378202e+04 >=     tree is empty   0.0% (0; 1781)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   2.2 secs
# Memory used: 4.0 Mb (4227460 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmpnsbv5bi1.glpk.raw'...
# 1771 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmp58jeeiwr.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmp4q5t8tnj.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpxv9n6x16.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpxv9n6x16.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpxv9n6x16.pyomo.lp:8544: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpxv9n6x16.pyomo.lp:8544: warning: upper bound of variable 'x2' redefined
# 956 rows, 812 columns, 4042 non-zeros
# 812 integer variables, all of which are binary
# 9356 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmp4q5t8tnj.glpk.glp'...
# 7581 lines were written
# GLPK Integer Optimizer, v4.65
# 956 rows, 812 columns, 4042 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 86 hidden covering inequaliti(es) were detected
# 956 rows, 812 columns, 4042 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 955
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 956 rows, 812 columns, 4042 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   330: >>>>>   2.860528503e+04 >=   2.526161003e+04  11.7% (17; 0)
# +   443: >>>>>   2.818980535e+04 >=   2.528608551e+04  10.3% (30; 11)
# +   655: >>>>>   2.812594068e+04 >=   2.602783447e+04   7.5% (61; 16)
# +   821: >>>>>   2.804580973e+04 >=   2.605568523e+04   7.1% (90; 25)
# +   896: >>>>>   2.781326426e+04 >=   2.605568523e+04   6.3% (100; 31)
# +  1019: >>>>>   2.770304114e+04 >=   2.611395180e+04   5.7% (101; 50)
# +  1541: >>>>>   2.750102236e+04 >=   2.627777327e+04   4.4% (162; 80)
# +  6732: >>>>>   2.748329243e+04 >=   2.680305511e+04   2.5% (618; 311)
# + 11370: >>>>>   2.742682635e+04 >=   2.710075783e+04   1.2% (691; 801)
# + 15315: >>>>>   2.742529517e+04 >=   2.734912809e+04   0.3% (227; 2175)
# + 15959: mip =   2.742529517e+04 >=     tree is empty   0.0% (0; 3241)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   3.7 secs
# Memory used: 4.8 Mb (5025958 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmp58jeeiwr.glpk.raw'...
# 1777 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmpkxdrce3m.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmp33jvs8kg.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpqsn80h7z.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpqsn80h7z.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpqsn80h7z.pyomo.lp:8646: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpqsn80h7z.pyomo.lp:8646: warning: upper bound of variable 'x2' redefined
# 962 rows, 812 columns, 4126 non-zeros
# 812 integer variables, all of which are binary
# 9458 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmp33jvs8kg.glpk.glp'...
# 7677 lines were written
# GLPK Integer Optimizer, v4.65
# 962 rows, 812 columns, 4126 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 92 hidden covering inequaliti(es) were detected
# 962 rows, 812 columns, 4126 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 961
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 962 rows, 812 columns, 4126 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   344: >>>>>   2.838352272e+04 >=   2.526161003e+04  11.0% (17; 0)
# +   546: >>>>>   2.812983593e+04 >=   2.593941931e+04   7.8% (49; 3)
# +   667: >>>>>   2.812594068e+04 >=   2.602783447e+04   7.5% (59; 10)
# +   845: >>>>>   2.775633929e+04 >=   2.605568523e+04   6.1% (88; 12)
# +  1644: >>>>>   2.758512367e+04 >=   2.627777327e+04   4.7% (177; 54)
# +  6771: >>>>>   2.748329243e+04 >=   2.680305511e+04   2.5% (653; 287)
# + 15495: >>>>>   2.743400210e+04 >=   2.729154631e+04   0.5% (607; 1586)
# + 17208: mip =   2.743400210e+04 >=     tree is empty   0.0% (0; 3725)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   4.1 secs
# Memory used: 5.2 Mb (5501890 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmpkxdrce3m.glpk.raw'...
# 1783 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmp6uhf81kf.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmpx9nhpdck.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmp8zgeqo8y.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmp8zgeqo8y.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmp8zgeqo8y.pyomo.lp:8748: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmp8zgeqo8y.pyomo.lp:8748: warning: upper bound of variable 'x2' redefined
# 968 rows, 812 columns, 4210 non-zeros
# 812 integer variables, all of which are binary
# 9560 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmpx9nhpdck.glpk.glp'...
# 7773 lines were written
# GLPK Integer Optimizer, v4.65
# 968 rows, 812 columns, 4210 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 98 hidden covering inequaliti(es) were detected
# 968 rows, 812 columns, 4210 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 967
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 968 rows, 812 columns, 4210 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   347: >>>>>   2.886024495e+04 >=   2.526161003e+04  12.5% (21; 0)
# +   457: >>>>>   2.815282104e+04 >=   2.528608551e+04  10.2% (41; 1)
# +   584: >>>>>   2.779635690e+04 >=   2.593941931e+04   6.7% (52; 20)
# +  3497: >>>>>   2.759362236e+04 >=   2.650668641e+04   3.9% (418; 92)
# +  5587: >>>>>   2.748329243e+04 >=   2.669478185e+04   2.9% (585; 263)
# + 18233: mip =   2.748329243e+04 >=     tree is empty   0.0% (0; 3753)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   4.6 secs
# Memory used: 5.2 Mb (5470218 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmp6uhf81kf.glpk.raw'...
# 1789 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmprvlh1n4i.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmp_5e71oax.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpm4s6jlwy.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpm4s6jlwy.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpm4s6jlwy.pyomo.lp:8866: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpm4s6jlwy.pyomo.lp:8866: warning: upper bound of variable 'x2' redefined
# 976 rows, 812 columns, 4304 non-zeros
# 812 integer variables, all of which are binary
# 9678 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmp_5e71oax.glpk.glp'...
# 7883 lines were written
# GLPK Integer Optimizer, v4.65
# 976 rows, 812 columns, 4304 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 106 hidden covering inequaliti(es) were detected
# 976 rows, 812 columns, 4304 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 975
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 976 rows, 812 columns, 4304 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   223: obj =   2.359608513e+04 inf =   2.204e-14 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   223: mip =     not found yet >=              -inf        (1; 0)
# +   391: >>>>>   2.856934583e+04 >=   2.526161003e+04  11.6% (34; 0)
# +   502: >>>>>   2.853454040e+04 >=   2.530568986e+04  11.3% (47; 4)
# +   596: >>>>>   2.814924702e+04 >=   2.595902366e+04   7.8% (59; 5)
# +   692: >>>>>   2.813642521e+04 >=   2.596886603e+04   7.7% (66; 12)
# +   876: >>>>>   2.791750343e+04 >=   2.600325158e+04   6.9% (92; 14)
# +  3487: >>>>>   2.789022810e+04 >=   2.648697212e+04   5.0% (449; 92)
# +  3879: >>>>>   2.778270070e+04 >=   2.650668641e+04   4.6% (497; 106)
# +  3992: >>>>>   2.773902624e+04 >=   2.651527726e+04   4.4% (476; 168)
# +  4316: >>>>>   2.770184276e+04 >=   2.656242306e+04   4.1% (514; 195)
# +  6049: >>>>>   2.763977783e+04 >=   2.671679663e+04   3.3% (661; 291)
# + 12691: >>>>>   2.758450253e+04 >=   2.704664175e+04   1.9% (1063; 697)
# + 26583: mip =   2.758450253e+04 >=     tree is empty   0.0% (0; 5319)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   6.2 secs
# Memory used: 7.0 Mb (7371170 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmprvlh1n4i.glpk.raw'...
# 1797 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmpmuf3yqhq.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmpfc0xo541.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpr3sp8_cv.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpr3sp8_cv.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpr3sp8_cv.pyomo.lp:8984: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpr3sp8_cv.pyomo.lp:8984: warning: upper bound of variable 'x2' redefined
# 984 rows, 812 columns, 4398 non-zeros
# 812 integer variables, all of which are binary
# 9796 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmpfc0xo541.glpk.glp'...
# 7993 lines were written
# GLPK Integer Optimizer, v4.65
# 984 rows, 812 columns, 4398 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 114 hidden covering inequaliti(es) were detected
# 984 rows, 812 columns, 4398 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 983
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 984 rows, 812 columns, 4398 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   8.247e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   334: >>>>>   2.868938634e+04 >=   2.526161003e+04  11.9% (18; 0)
# +   463: >>>>>   2.820315722e+04 >=   2.528608551e+04  10.3% (34; 6)
# +   895: >>>>>   2.820170232e+04 >=   2.609434745e+04   7.5% (95; 20)
# +  1237: >>>>>   2.794157056e+04 >=   2.620499097e+04   6.2% (142; 25)
# +  2497: >>>>>   2.793286250e+04 >=   2.636243204e+04   5.6% (318; 61)
# +  3703: >>>>>   2.771740929e+04 >=   2.648697212e+04   4.4% (465; 87)
# +  3834: >>>>>   2.770184276e+04 >=   2.649753078e+04   4.3% (432; 172)
# +  6493: >>>>>   2.758512367e+04 >=   2.669196207e+04   3.2% (721; 266)
# + 27669: mip =   2.758512367e+04 >=   2.752009529e+04   0.2% (428; 3935)
# + 28787: mip =   2.758512367e+04 >=     tree is empty   0.0% (0; 6013)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   6.9 secs
# Memory used: 7.5 Mb (7910434 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmpmuf3yqhq.glpk.raw'...
# 1805 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\Ashish\AppData\Local\Temp\tmp2nyl_ulg.glpk.raw --wglp C:\Users\Ashish\AppData\Local\Temp\tmpssavn75m.glpk.glp
#  --cpxlp C:\Users\Ashish\AppData\Local\Temp\tmpu2oz_bec.pyomo.lp
# Reading problem data from 'C:\Users\Ashish\AppData\Local\Temp\tmpu2oz_bec.pyomo.lp'...
# C:\Users\Ashish\AppData\Local\Temp\tmpu2oz_bec.pyomo.lp:9086: warning: lower bound of variable 'x2' redefined
# C:\Users\Ashish\AppData\Local\Temp\tmpu2oz_bec.pyomo.lp:9086: warning: upper bound of variable 'x2' redefined
# 990 rows, 812 columns, 4482 non-zeros
# 812 integer variables, all of which are binary
# 9898 lines were read
# Writing problem data to 'C:\Users\Ashish\AppData\Local\Temp\tmpssavn75m.glpk.glp'...
# 8089 lines were written
# GLPK Integer Optimizer, v4.65
# 990 rows, 812 columns, 4482 non-zeros
# 812 integer variables, all of which are binary
# Preprocessing...
# 120 hidden covering inequaliti(es) were detected
# 990 rows, 812 columns, 4482 non-zeros
# 812 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 989
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 990 rows, 812 columns, 4482 non-zeros
#       0: obj =   1.607244553e+05 inf =   1.820e+02 (57)
#      84: obj =   5.450933583e+04 inf =   0.000e+00 (0)
# *   219: obj =   2.359608513e+04 inf =   7.803e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   219: mip =     not found yet >=              -inf        (1; 0)
# +   357: >>>>>   2.922602858e+04 >=   2.526161003e+04  13.6% (23; 0)
# +   480: >>>>>   2.856050676e+04 >=   2.528608551e+04  11.5% (43; 6)
# +   927: >>>>>   2.816780842e+04 >=   2.605568523e+04   7.5% (111; 27)
# +  1010: >>>>>   2.798459486e+04 >=   2.605568523e+04   6.9% (103; 61)
# +  1077: >>>>>   2.780128962e+04 >=   2.609434745e+04   6.1% (96; 85)
# +  3831: >>>>>   2.778270070e+04 >=   2.650668641e+04   4.6% (421; 166)
# +  4518: >>>>>   2.773902624e+04 >=   2.654878196e+04   4.3% (500; 194)
# +  5035: >>>>>   2.771645044e+04 >=   2.657024050e+04   4.1% (557; 222)
# +  7087: >>>>>   2.760117377e+04 >=   2.677160708e+04   3.0% (750; 311)
# + 27730: mip =   2.760117377e+04 >=   2.757930540e+04 < 0.1% (141; 4993)
# + 27978: mip =   2.760117377e+04 >=     tree is empty   0.0% (0; 5957)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   6.8 secs
# Memory used: 7.3 Mb (7625080 bytes)
# Writing MIP solution to 'C:\Users\Ashish\AppData\Local\Temp\tmp2nyl_ulg.glpk.raw'...
# 1811 lines were written
# Optimal path found
# Objective value is 27601.17377449376
# Code took 73.07840347290039 seconds to execute
# Active arcs are [(0, 1), (1, 5), (2, 3), (3, 7), (4, 0), (5, 9), (6, 2), (7, 4), (8, 6), (9, 10), (10, 11), (11, 14), (12, 8), (13, 12), (14, 18), (15, 13), (16, 20), (17, 16), (18, 17), (19, 24), (20, 21), (21, 22), (22, 28), (23, 15), (24, 26), (25, 19), (26, 23), (27, 25), (28, 27)]

# %% [markdown]
# Writing the result file

# %% [markdown]
# Creating the video from the Images

# %%
#Creating a Video of the Images

import os
from PIL import Image
import cv2

current_path = os.getcwd()
print(current_path)
img_dir = "Output\\Images"

def compute_average_dimensions(folder):
    total_width = 0
    total_height = 0
    img_count = 0

    for img_file in os.listdir(folder):
        if img_file.endswith((".jpg", ".jpeg", ".png")):
            image = Image.open(os.path.join(folder, img_file))
            w, h = image.size
            total_width += w
            total_height += h
            img_count += 1

    avg_width = int(total_width / img_count)
    avg_height = int(total_height / img_count)
    return avg_width, avg_height

# Calculate average dimensions of images
avg_width, avg_height = compute_average_dimensions(img_dir)


video_filename = 'Output\\created_video.mp4'
valid_images = [i for i in os.listdir(img_dir) if i.endswith((".jpg", ".jpeg", ".png"))]

valid_images = [f'frame_{i}.png' for i in range(0,len(valid_images))]

first_image = cv2.imread(os.path.join(img_dir, valid_images[0]))
h, w, _ = first_image.shape

codec = cv2.VideoWriter_fourcc(*'mp4v')
vid_writer = cv2.VideoWriter(video_filename, codec, 60, (w, h))

for img in valid_images:
    loaded_img = cv2.imread(os.path.join(img_dir, img))
    for _ in range(20):
        vid_writer.write(loaded_img)

vid_writer.release()
# Out:
# e:\Self Projects\MILP\Travelling Salesman Problem
